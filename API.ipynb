# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
import numpy as np
import seaborn as sns
import time
import datetime
from pprint import pprint
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "https://data.cdc.gov/resource/w9j2-ggv5.json" 
print(requests.get(url).json())
# Out:
# [{'year': '1900', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '47.3', 'mortality': '2518.0'}, {'year': '1901', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '49.1', 'mortality': '2473.1'}, {'year': '1902', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '51.5', 'mortality': '2301.3'}, {'year': '1903', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '50.5', 'mortality': '2379.0'}, {'year': '1904', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '47.6', 'mortality': '2502.5'}, {'year': '1905', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '48.7', 'mortality': '2423.7'}, {'year': '1906', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '48.7', 'mortality': '2399.0'}, {'year': '1907', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '47.6', 'mortality': '2494.4'}, {'year': '1908', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '51.1', 'mortality': '2298.9'}, {'year': '1909', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '52.1', 'mortality': '2249.2'}, {'year': '1910', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '50', 'mortality': '2317.2'}, {'year': '1911', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '52.6', 'mortality': '2245.4'}, {'year': '1912', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '53.5', 'mortality': '2211.7'}, {'year': '1913', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '52.5', 'mortality': '2206.5'}, {'year': '1914', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '54.2', 'mortality': '2149.3'}, {'year': '1915', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '54.5', 'mortality': '2174.8'}, {'year': '1916', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '51.7', 'mortality': '2266.6'}, {'year': '1917', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '50.9', 'mortality': '2275.9'}, {'year': '1918', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '39.1', 'mortality': '2541.6'}, {'year': '1919', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '54.7', 'mortality': '2057.2'}, {'year': '1920', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '54.1', 'mortality': '2147.1'}, {'year': '1921', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '60.8', 'mortality': '1958.2'}, {'year': '1922', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '59.6', 'mortality': '2049.5'}, {'year': '1923', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '57.2', 'mortality': '2141.4'}, {'year': '1924', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '59.7', 'mortality': '2038.0'}, {'year': '1925', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '59', 'mortality': '2068.7'}, {'year': '1926', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '56.7', 'mortality': '2146.2'}, {'year': '1927', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '60.4', 'mortality': '1989.5'}, {'year': '1928', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '56.8', 'mortality': '2124.6'}, {'year': '1929', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '57.1', 'mortality': '2081.2'}, {'year': '1930', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '59.7', 'mortality': '1943.8'}, {'year': '1931', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '61.1', 'mortality': '1895.1'}, {'year': '1932', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '62.1', 'mortality': '1897.1'}, {'year': '1933', 'race': 'All Races', 'sex': 'Both Sexes', 'average_life_expectancy': '63.3', 'mortality': '1 ...

# %%
        year.append(response['year'])
        race.append(response['race'])
        Gender.append(response['sex'])
Death = pd.DataFrame({
    "Year":year,
    "Race":race, 
    "Gender":sex,
})
Death.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a4878d8ccd51> in <module>
# ----> 1 year.append(response['year'])
#       2 race.append(response['race'])
#       3 Gender.append(response['sex'])
#       4 Death = pd.DataFrame({
#       5     "Year":year,
#
# NameError: name 'year' is not defined

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
City_weather = pd.DataFrame({
    "City":city,
    "Temperature":max_temp, 
    "Humidity":humidity, 
    "Clouds":cloudiness, 
    "Wind Speed":wind_speed, 
    "Longitude":lng,
    "Latitude":lat,
})


City_weather.head()
# Out:
#         City  Temperature  Humidity  Clouds  Wind Speed  Longitude  Latitude
# 0  contamana        57.99        76      90        5.82     -79.24     42.10
# 1  contamana        57.00        90      81        8.30     115.33    -33.65
# 2  contamana        82.99        74      80        8.84      73.08     -0.60
# 3  contamana        68.38        23       0        5.26      19.77    -17.93
# 4  contamana        71.60        88      40       11.41      57.70    -20.41

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
new_df=City_weather[City_weather.Humidity>100]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
City_weather.to_csv("../output_data/city_weather.csv", index=False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(City_weather["Latitude"], City_weather["Temperature"], marker="o",s=10)

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(City_weather["Latitude"], City_weather["Humidity"], marker="o",s=10)

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(City_weather["Latitude"], City_weather["Clouds"], marker="o",s=10)

plt.title("City Latitude vs. Clouds")
plt.ylabel("Clouds")
plt.xlabel("Latitude")
plt.grid(True)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(City_weather["Latitude"], City_weather["Wind Speed"], marker="o",s=10)

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
data = pd.read_csv("../output_data/city_weather.csv")
X = data.iloc[:, 0].values.reshape(-1, 1)
Y = data.iloc[:, 1].values.reshape(-1, 1)
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)
plt.grid(True)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
