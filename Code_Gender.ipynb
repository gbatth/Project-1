# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
from functools import reduce
# Out:
# Using matplotlib backend: Qt5Agg

# %%
file1 = "Resources/Underlying Cause of Death, 1999_2018_Gender.xlsx"
df = pd.read_excel(file1)

# %%
df.head()
# Out:
#   Notes    State  State Code  Gender Gender Code    Year  Year Code   Deaths  \
# 0   NaN  Alabama         1.0  Female           F  1999.0     1999.0  22603.0
# 1   NaN  Alabama         1.0  Female           F  2000.0     2000.0  22709.0
# 2   NaN  Alabama         1.0  Female           F  2001.0     2001.0  23129.0
# 3   NaN  Alabama         1.0  Female           F  2002.0     2002.0  23423.0
# 4   NaN  Alabama         1.0  Female           F  2003.0     2003.0  23812.0
#
#    Population  Crude Rate
# 0   2293259.0       985.6
# 1   2300596.0       987.1
# 2   2309496.0      1001.5
# 3   2314370.0      1012.1
# 4   2324069.0      1024.6

# %%
table=pd.pivot_table(df, values=['Deaths','Population'], index=['State','Year'], columns=['Gender'], aggfunc=np.sum)
table
# Out:
#                  Deaths          Population
# Gender           Female     Male     Female       Male
# State   Year
# Alabama 1999.0  22603.0  22203.0  2293259.0  2136882.0
#         2000.0  22709.0  22353.0  2300596.0  2146504.0
#         2001.0  23129.0  22187.0  2309496.0  2158138.0
#         2002.0  23423.0  22646.0  2314370.0  2165719.0
#         2003.0  23812.0  22904.0  2324069.0  2179422.0
# ...                 ...      ...        ...        ...
# Wyoming 2014.0   2192.0   2474.0   286111.0   298042.0
#         2015.0   2228.0   2550.0   287206.0   298901.0
#         2016.0   2208.0   2514.0   286559.0   298942.0
#         2017.0   2229.0   2539.0   283877.0   295438.0
#         2018.0   2394.0   2676.0   283203.0   294534.0
#
# [1020 rows x 4 columns]

# %%
table.to_csv("Resources/table_gender.csv", index=True)

# %%
df.isnull().sum()
# Out:
# Notes          2040
# State            42
# State Code       42
# Gender           93
# Gender Code      93
# Year            195
# Year Code       195
# Deaths           41
# Population       41
# Crude Rate       41
# dtype: int64

# %%
df.describe()
# Out:
#         State Code         Year    Year Code        Deaths    Population  \
# count  2193.000000  2040.000000  2040.000000  2.194000e+03  2.194000e+03
# mean     28.960784  2008.500000  2008.500000  9.219284e+04  1.110052e+07
# std      15.680411     5.767695     5.767695  1.107951e+06  1.338593e+08
# min       1.000000  1999.000000  1999.000000  1.166000e+03  2.445180e+05
# 25%      16.000000  2003.750000  2003.750000  7.205250e+03  8.976352e+05
# 50%      29.000000  2008.500000  2008.500000  2.002200e+04  2.274225e+06
# 75%      42.000000  2013.250000  2013.250000  3.563275e+04  4.371752e+06
# max      56.000000  2018.000000  2018.000000  5.056777e+07  6.088633e+09
#
#         Crude Rate
# count  2194.000000
# mean    857.588833
# std     132.303566
# min     387.000000
# 25%     775.175000
# 50%     862.000000
# 75%     946.675000
# max    1356.400000

# %%
g=sns.relplot(x='Year',y='Crude Rate', data=df, kind="line",col='Gender')
fig = plt.gcf()
fig.set_size_inches(20, 10)
g.set_xticklabels(rotation=90)

# %%
ax = sns.pairplot(df)

# %%
g= sns.relplot(x='Year',y='Crude Rate', kind='line', data=df, col='State')
fig = plt.gcf()
fig.set_size_inches(20, 10)
g.set_xticklabels(rotation=90)

# %%
g= sns.factorplot(x='State',y='Crude Rate', data=df)
fig = plt.gcf()
fig.set_size_inches(12, 10)
g.set_xticklabels(rotation=90)
# Out:
# C:\Users\sbatt\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
g= sns.catplot(x='State',y='Rate', hue="Gender", data=df, kind="swarm")
fig = plt.gcf()
fig.set_size_inches(20, 10)
g.set_xticklabels(rotation=90)

# %%
df1=pandas.read_clipboard()
df1.plot.bar(x='Year')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e88d8974bacc> in <module>
# ----> 1 df1=pandas.read_clipboard()
#       2 df1.plot.bar(x='Year')
#
# NameError: name 'pandas' is not defined
